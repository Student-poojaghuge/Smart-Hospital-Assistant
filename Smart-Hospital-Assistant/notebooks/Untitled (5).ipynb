# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib seaborn scikit-learn joblib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import pandas as pd
from pathlib import Path

# Exact location of your CSV file
file_path = Path(r"C:\Users\hp\OneDrive\Desktop\smart_hospital_assistant\data\raw\heart_disease_uci.csv")

print("File exists:", file_path.exists())

df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
print("Dataset shape:", df.shape)
print(df.head())
# Out:
# File exists: True
# Dataset loaded successfully!
# Dataset shape: (920, 16)
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# ...

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.tail()
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak slope  ca          thal  num
# 915  st-t abnormality   154.0  False      0.0   NaN NaN           NaN    1
# 916  st-t abnormality     NaN    NaN      NaN   NaN NaN           NaN    0
# 917  st-t abnormality   100.0  False      0.0   NaN NaN  fixed defect    2
# 918    lv hypertrophy     NaN    NaN      NaN   NaN NaN           NaN    0
# 919    lv hypertrophy    93.0   True      0.0   NaN NaN           NaN    1

# %%
df.sample(5)
# Out:
#       id  age     sex        dataset            cp  trestbps   chol    fbs  \
# 512  513   49  Female        Hungary   non-anginal     160.0  180.0  False
# 836  837   55    Male  VA Long Beach  asymptomatic     116.0  186.0   True
# 907  908   58    Male  VA Long Beach   non-anginal     150.0  219.0  False
# 302  303   38    Male      Cleveland   non-anginal     138.0  175.0  False
# 917  918   55    Male  VA Long Beach  asymptomatic     122.0  223.0   True
#
#               restecg  thalch  exang  oldpeak      slope  ca          thal  \
# 512            normal   156.0  False      1.0       flat NaN           NaN
# 836  st-t abnormality   102.0  False      0.0        NaN NaN           NaN
# 907  st-t abnormality   118.0   True      0.0        NaN NaN           NaN
# 302            normal   173.0  False      0.0  upsloping NaN        normal
# 917  st-t abnormality   100.0  False      0.0        NaN NaN  fixed defect
#
#      num
# 512    1
# 836    2
# 907    2
# 302    0
# 917    2

# %%
print("Number of rows and columns:", df.shape)

print("\nColumn names:")
print(df.columns.tolist())

print("\nDataset information:")
df.info()
# Out:
# Number of rows and columns: (920, 16)
#
# Column names:
# ['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']
#
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    str
#  3   dataset   920 non-null    str
#  4   cp        920 non-null    str
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    str
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    str
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    str
# ...

# %%
df.describe(include="all").T
# Out:
#           count unique           top freq        mean         std   min  \
# id        920.0    NaN           NaN  NaN       460.5  265.725422   1.0
# age       920.0    NaN           NaN  NaN    53.51087    9.424685  28.0
# sex         920      2          Male  726         NaN         NaN   NaN
# dataset     920      4     Cleveland  304         NaN         NaN   NaN
# cp          920      4  asymptomatic  496         NaN         NaN   NaN
# trestbps  861.0    NaN           NaN  NaN  132.132404    19.06607   0.0
# chol      890.0    NaN           NaN  NaN  199.130337   110.78081   0.0
# fbs         830      2         False  692         NaN         NaN   NaN
# restecg     918      3        normal  551         NaN         NaN   NaN
# thalch    865.0    NaN           NaN  NaN  137.545665   25.926276  60.0
# exang       865      2         False  528         NaN         NaN   NaN
# oldpeak   858.0    NaN           NaN  NaN    0.878788    1.091226  -2.6
# ...

# %%
missing_values=df.isnull().sum()
print("missing values in each column:")
print(missing_values)
# Out:
# missing values in each column:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100

missing_table = pd.DataFrame({
    "Missing Count": df.isnull().sum(),
    "Missing Percentage": missing_percentage
})

missing_table
# Out:
#           Missing Count  Missing Percentage
# id                    0            0.000000
# age                   0            0.000000
# sex                   0            0.000000
# dataset               0            0.000000
# cp                    0            0.000000
# trestbps             59            6.413043
# chol                 30            3.260870
# fbs                  90            9.782609
# restecg               2            0.217391
# thalch               55            5.978261
# exang                55            5.978261
# oldpeak              62            6.739130
# slope               309           33.586957
# ca                  611           66.413043
# thal                486           52.826087
# num                   0            0.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
# ...

# %%
df = df.drop_duplicates()

print("Shape after removing duplicates:", df.shape)
# Out:
# Shape after removing duplicates: (920, 16)

# %%
print(df.columns.tolist())
# Out:
# ['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num']

# %%
if "num" in df.columns:
    df = df.rename(columns={"num": "target"})

print(df.columns.tolist())
# Out:
# ['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
print(df["target"].value_counts(dropna=False))
# Out:
# target
# 0    411
# 1    265
# 2    109
# 3    107
# 4     28
# Name: count, dtype: int64

# %%
df["target"] = pd.to_numeric(df["target"], errors="coerce")

df["target"] = (df["target"] > 0).astype("Int64")

print(df["target"].value_counts(dropna=False))
# Out:
# target
# 1    509
# 0    411
# Name: count, dtype: Int64

# %%
for column in df.columns:
    if column != "target":
        converted_column = pd.to_numeric(df[column], errors="ignore")
        df[column] = converted_column
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 for column in df.columns:
#       2     if column != "target":
# ----> 3         converted_column = pd.to_numeric(df[column], errors="ignore")
#       4         df[column] = converted_column
#
# File ~\OneDrive\Desktop\smart_hospital_assistant\.venv\Lib\site-packages\pandas\core\tools\numeric.py:183, in to_numeric(arg, errors, downcast, dtype_backend)
#     180     raise ValueError("invalid downcasting method provided")
#     182 if errors not in ("raise", "coerce"):
# --> 183     raise ValueError("invalid error value specified")
#     185 check_dtype_backend(dtype_backend)
#     187 is_series = False
#
# ValueError: invalid error value specified

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# target        0
# dtype: int64

# %%
columns_to_drop = []

for column in ["id", "dataset"]:
    if column in df.columns:
        columns_to_drop.append(column)

df = df.drop(columns=columns_to_drop)

print("Removed columns:", columns_to_drop)
print("Remaining columns:", df.columns.tolist())
# Out:
# Removed columns: ['id', 'dataset']
# Remaining columns: ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
df = df.dropna(subset=["target"])

print("Shape after removing missing target values:", df.shape)
# Out:
# Shape after removing missing target values: (920, 14)

# %%
output_folder = Path("processed_data")
output_folder.mkdir(exist_ok=True)

cleaned_file = output_folder / "heart_disease_cleaned.csv"

df.to_csv(cleaned_file, index=False)

print("Cleaned dataset saved at:", cleaned_file)
# Out:
# Cleaned dataset saved at: processed_data\heart_disease_cleaned.csv

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="target")

plt.title("Heart Disease Distribution")
plt.xlabel("Target: 0 = No Disease, 1 = Disease")
plt.ylabel("Number of Patients")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 plt.figure(figsize=(6, 4))
#       2
# ----> 3 sns.countplot(data=df, x="target")
#       4
#       5 plt.title("Heart Disease Distribution")
#       6 plt.xlabel("Target: 0 = No Disease, 1 = Disease")
#
# NameError: name 'sns' is not defined

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df,x="age",bins=20,kde=True)

plt.title("Age distribution")
plt.xlabel("Age")
plt.ylabel("count")

plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df,x="target",y="age")

plt.title("Age vs heart disease")
plt.xlabel("target")
plt.ylabel("age")


plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="sex",hue="target")

plt.title("heart disease distribution by gender")
plt.xlabel("sex")
plt.ylabel("target")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 plt.figure(figsize=(8,5))
# ----> 2 sns.countplot(data=df,x="sex",hue="target")
#       3
#       4 plt.title("heart disease distribution by gender")
#       5 plt.xlabel("sex")
#
# NameError: name 'sns' is not defined

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="chol", bins=25, kde=True)

plt.title("Cholesterol Distribution")
plt.xlabel("Cholesterol")
plt.ylabel("Count")

plt.show()

# %%
import numpy as np

# %%
import seaborn as sns

# %%
numeric_df=df.select_dtypes(include=np.number)
plt.figure(figsize=(12,8))
sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("feature correlation heatmap")
plt.show()

# %%
df.dtypes
# Out:
# age           int64
# sex             str
# cp              str
# trestbps    float64
# chol        float64
# fbs          object
# restecg         str
# thalch      float64
# exang        object
# oldpeak     float64
# slope           str
# ca          float64
# thal            str
# target        Int64
# dtype: object

# %%
print("Missing target values:", df["target"].isnull().sum())
# Out:
# Missing target values: 0

# %%
print("Final dataset shape:", df.shape)
print("Total duplicate rows:", df.duplicated().sum())
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Final dataset shape: (920, 14)
# Total duplicate rows: 2
# Total missing values: 1759

# %%
X = df.drop(columns=["target"])
y = df["target"].astype(int)

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (920, 13)
# Target shape: (920,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (736, 13)
# Testing data: (184, 13)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

numeric_features = X_train.select_dtypes(
    include=["int64", "float64", "int32", "float32"]
).columns.tolist()

categorical_features = X_train.select_dtypes(
    exclude=["int64", "float64", "int32", "float32"]
).columns.tolist()

print("Numerical features:", numeric_features)
print("Categorical features:", categorical_features)
# Out:
# Numerical features: ['age', 'trestbps', 'chol', 'thalch', 'oldpeak', 'ca']
# Categorical features: ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'thal']

# %%
numeric_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# %%
categorical_pipeline = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("numeric", numeric_pipeline, numeric_features),
        ("categorical", categorical_pipeline, categorical_features)
    ]
)

print("Preprocessing pipeline created successfully!")
# Out:
# Preprocessing pipeline created successfully!

# %%
from sklearn.linear_model import LogisticRegression

logistic_model=Pipeline(steps=[
    ("preprocessor",preprocessor),
    ("classifier",LogisticRegression(max_iter=2000))
])
logistic_model.fit(X_train,y_train)
print("Logistic Regression model trained successfully!")
# Out:
# Logistic Regression model trained successfully!

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_model=Pipeline(steps=[
    ("preprocessor",preprocessor),
     ("classifier",RandomForestClassifier(
         n_estimators=200,
         random_state=42,
         class_weight="balanced"
     ))
     ])
random_forest_model.fit(X_train,y_train)
print("Random forest model traind successfully!")
# Out:
# Random forest model traind successfully!

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

# %%
logistic_predictions = logistic_model.predict(X_test)
logistic_probabilities = logistic_model.predict_proba(X_test)[:, 1]

print("Logistic Regression Results")
print("---------------------------")

print("Accuracy:", accuracy_score(y_test, logistic_predictions))
print("Precision:", precision_score(y_test, logistic_predictions, zero_division=0))
print("Recall:", recall_score(y_test, logistic_predictions, zero_division=0))
print("F1 Score:", f1_score(y_test, logistic_predictions, zero_division=0))
print("ROC-AUC:", roc_auc_score(y_test, logistic_probabilities))

print("\nClassification Report:")
print(classification_report(y_test, logistic_predictions, zero_division=0))
# Out:
# Logistic Regression Results
# ---------------------------
# Accuracy: 0.842391304347826
# Precision: 0.8411214953271028
# Recall: 0.8823529411764706
# F1 Score: 0.861244019138756
# ROC-AUC: 0.9035150645624103
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.82        82
#            1       0.84      0.88      0.86       102
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.84      0.84       184
# weighted avg       0.84      0.84      0.84       184

# %%
rf_predictions = random_forest_model.predict(X_test)
rf_probabilities = random_forest_model.predict_proba(X_test)[:, 1]

print("Random Forest Results")
print("--------------------")

print("Accuracy:", accuracy_score(y_test, rf_predictions))
print("Precision:", precision_score(y_test, rf_predictions, zero_division=0))
print("Recall:", recall_score(y_test, rf_predictions, zero_division=0))
print("F1 Score:", f1_score(y_test, rf_predictions, zero_division=0))
print("ROC-AUC:", roc_auc_score(y_test, rf_probabilities))

print("\nClassification Report:")
print(classification_report(y_test, rf_predictions, zero_division=0))
# Out:
# Random Forest Results
# --------------------
# Accuracy: 0.842391304347826
# Precision: 0.8613861386138614
# Recall: 0.8529411764705882
# F1 Score: 0.8571428571428571
# ROC-AUC: 0.9219273075083693
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82        82
#            1       0.86      0.85      0.86       102
#
#     accuracy                           0.84       184
#    macro avg       0.84      0.84      0.84       184
# weighted avg       0.84      0.84      0.84       184

# %%
cm = confusion_matrix(y_test, rf_predictions)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Random Forest Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")

plt.show()

# %%
model_comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest"
    ],
    "Accuracy": [
        accuracy_score(y_test, logistic_predictions),
        accuracy_score(y_test, rf_predictions)
    ],
    "Precision": [
        precision_score(y_test, logistic_predictions, zero_division=0),
        precision_score(y_test, rf_predictions, zero_division=0)
    ],
    "Recall": [
        recall_score(y_test, logistic_predictions, zero_division=0),
        recall_score(y_test, rf_predictions, zero_division=0)
    ],
    "F1 Score": [
        f1_score(y_test, logistic_predictions, zero_division=0),
        f1_score(y_test, rf_predictions, zero_division=0)
    ],
    "ROC-AUC": [
        roc_auc_score(y_test, logistic_probabilities),
        roc_auc_score(y_test, rf_probabilities)
    ]
})

model_comparison
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 0  Logistic Regression  0.842391   0.841121  0.882353  0.861244  0.903515
# 1        Random Forest  0.842391   0.861386  0.852941  0.857143  0.921927

# %%
model_comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest"
    ],
    "Accuracy": [
        accuracy_score(y_test, logistic_predictions),
        accuracy_score(y_test, rf_predictions)
    ],
    "Precision": [
        precision_score(y_test, logistic_predictions, zero_division=0),
        precision_score(y_test, rf_predictions, zero_division=0)
    ],
    "Recall": [
        recall_score(y_test, logistic_predictions, zero_division=0),
        recall_score(y_test, rf_predictions, zero_division=0)
    ],
    "F1 Score": [
        f1_score(y_test, logistic_predictions, zero_division=0),
        f1_score(y_test, rf_predictions, zero_division=0)
    ],
    "ROC-AUC": [
        roc_auc_score(y_test, logistic_probabilities),
        roc_auc_score(y_test, rf_probabilities)
    ]
})

model_comparison
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 0  Logistic Regression  0.842391   0.841121  0.882353  0.861244  0.903515
# 1        Random Forest  0.842391   0.861386  0.852941  0.857143  0.921927

# %%
import joblib

model_folder = Path("saved_models")
model_folder.mkdir(exist_ok=True)

joblib.dump(
    random_forest_model,
    model_folder / "heart_disease_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
loaded_model = joblib.load(
    model_folder / "heart_disease_model.pkl"
)

print("Saved model loaded successfully!")
# Out:
# Saved model loaded successfully!

# %%
# Out:
# c:\Users\hp\OneDrive\Desktop\smart_hospital_assistant\.venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator SimpleImputer from version 1.5.2 when using version 1.9.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\hp\OneDrive\Desktop\smart_hospital_assistant\.venv\Lib\site-packages\sklearn\base.py:525: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.5.2 when using version 1.9.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
sample_patient = X_test.iloc[[0]]

prediction = loaded_model.predict(sample_patient)
probability = loaded_model.predict_proba(sample_patient)[:, 1]

print("Predicted class:", int(prediction[0]))
print("Predicted probability:", round(float(probability[0]), 4))
# Out:
# Predicted class: 0
# Predicted probability: 0.395

# %%
import joblib
from pathlib import Path

model_path = Path(
    r"C:\Users\hp\OneDrive\Desktop\smart_hospital_assistant\models\heart_disease_model.pkl"
)

model_path.parent.mkdir(parents=True, exist_ok=True)

joblib.dump(random_forest_model, model_path)

print("Model copied to the project models folder!")
print("Saved at:", model_path)
# Out:
# Model copied to the project models folder!
# Saved at: C:\Users\hp\OneDrive\Desktop\smart_hospital_assistant\models\heart_disease_model.pkl

# %%
test_model = joblib.load(model_path)

print("Model loaded successfully!")
# Out:
# Model loaded successfully!
